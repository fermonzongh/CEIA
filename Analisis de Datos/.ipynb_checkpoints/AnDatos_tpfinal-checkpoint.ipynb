# %%
#instalando pycaret
import pandas as pd
# !pip install pycaret

from pycaret.utils import version
version()

# only run this cell if you are using google colab
from pycaret.utils import enable_colab
enable_colab()

# %%
import mlflow
from imblearn.combine import *
from sklearn.model_selection import train_test_split
from imblearn.combine import *

import matplotlib.pyplot as plt

# %%
#Importando dataset
dataset_path_cloud = '/content/data_playlist.csv'
df = pd.read_csv(dataset_path_cloud, delimiter=',')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
df.describe()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#        acousticness  danceability       duration      energy  \
# count    750.000000    750.000000     750.000000  750.000000
# mean       0.357394      0.596439  220112.733333    0.594188
# std        0.338405      0.172036   65587.690483    0.253301
# min        0.000001      0.107000   33840.000000    0.009250
# 25%        0.037150      0.480000  185490.250000    0.423250
# 50%        0.244500      0.606000  215108.500000    0.631500
# 75%        0.678500      0.715750  244236.750000    0.804750
# max        0.994000      0.986000  675360.000000    0.995000
#
#        instrumentalness         key    liveness    loudness        mode  \
# ...

# %%
df.head(5)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#    acousticness  danceability  duration  energy  instrumentalness  key  \
# 0         0.713         0.514    100125   0.521          0.816000    8
# 1         0.192         0.714    207019   0.614          0.000000    4
# 2         0.333         0.630    216200   0.455          0.000004    5
# 3         0.601         0.810    136413   0.221          0.210000    5
# 4         0.883         0.465    181440   0.459          0.000173    6
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1120   -14.835     0       0.0444  119.879               4    0.143
# ...

# %%
#checkeamos los tipos de variables del dataset
df.dtypes
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# acousticness        float64
# danceability        float64
# duration              int64
# energy              float64
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# mode                  int64
# speechiness         float64
# tempo               float64
# time_signature        int64
# valence             float64
# label                 int64
# dtype: object

# %%
#Checkeamos si el Dataset tiene null-values.
df.isnull().sum()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# acousticness        0
# danceability        0
# duration            0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# label               0
# dtype: int64

# %%
#Analizando correlaciones entre features graficamente.
sm = pd.plotting.scatter_matrix(df, figsize=(20, 20))
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
#checkeamos si los valores de salida estan valanceados en el Dataset
def getLabelCount(df,target):
    return sorted([( labelValue,len(df.loc[df[target] == labelValue]) ) for labelValue in df[target].unique()])

getLabelCount(df,'label')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# [(0, 298), (1, 452)]

# %% [markdown]
# IMPORTANTE: **El valor label de salida, no esta balanceado, deberiamos implementar algunos metodos para lograr esto. Ya que hay un 50% mas de valores '1' que '0'**

# %%
## Nuestra idea es aplicar AutoML ahora, para analizar las metricas del modelo y luego aplicar algunos algoritmos para 'ensuciar' el dataset.
## Luego, aplicar AutoML nuevamente para contrastar los resultados con el experimento anterior.

# %%
#Aplicar AutoML, en el setup podemos ver varias caracteristicas de dataset como por ejemplo, missing values, tipos de datos, y demas.
from pycaret.classification import *
clf1 = setup(data = df, 
             silent=True,
             target = 'label', 
            )
# Out:
#                                Description             Value
# 0                               session_id              4351
# 1                                   Target             label
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (750, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                10
# 7                     Categorical Features                 3
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (524, 27)
# 12                    Transformed Test Set         (226, 27)
# 13                      Shuffle Train-Test              True
# ...

# %%
##Comparamos los tipos de modelos aplicables, para analizar las metricas.
best_model = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# gbc          Gradient Boosting Classifier    0.8454  0.9108  0.8787  0.8693
# lightgbm  Light Gradient Boosting Machine    0.8453  0.9255  0.8789  0.8704
# rf               Random Forest Classifier    0.8378  0.9230  0.8565  0.8735
# et                 Extra Trees Classifier    0.8359  0.9215  0.8627  0.8658
# ada                  Ada Boost Classifier    0.8111  0.8906  0.8660  0.8300
# ridge                    Ridge Classifier    0.8090  0.0000  0.8372  0.8448
# lda          Linear Discriminant Analysis    0.8052  0.8951  0.8627  0.8237
# dt               Decision Tree Classifier    0.7767  0.7693  0.8085  0.8202
# nb                            Naive Bayes    0.6851  0.7805  0.5721  0.8562
# lr                    Logistic Regression    0.6108  0.6236  0.8908  0.6358
# dummy                    Dummy Classifier    0.5973  0.5000  1.0000  0.5973
# ...
